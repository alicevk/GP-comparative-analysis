# %% [markdown]
# # Overall scores comparison
#
# <hr>
#
# This notebook displays a brief comparison between all of the models tested, based on two scoring methods: ROC-AUC and accuracy, both performed in 10-fold cross-validation.
#
# <hr>

# %%
# Import needed libraries and modules
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data
df = pd.concat([
    pd.read_csv('../2-GP-Implementation/scores.csv', index_col=0),
    # pd.read_csv('../3-Hyperparameter-Optimization/scores.csv', index_col=0),
    pd.read_csv('../4-Alternative-Models/scores.csv', index_col=0)
], axis=1)

model_df = df.iloc[:, df.columns.str.contains('model')]
optim_df = df.iloc[:, df.columns.str.contains('optimization')]

# Display
display(model_df)
display(optim_df)
# Out:
#               scikit-model  gpytorch-model  pyro-model  k-NN-model  RNC-model  \
# Accuracy          0.851724        0.842069    0.730920    0.804828   0.552184
# Accuracy STD      0.057077        0.038783    0.065671    0.071853   0.013805
# AUC-ROC           0.908070        0.911898    0.738302    0.854997   0.514286
# AUC-ROC STD       0.034690        0.036908    0.067041    0.062634   0.017496
#
#               LR-model  DT-model  SVM-SVC-model  SVM-NuSVC-model  \
# Accuracy      0.844828  0.757241       0.831379         0.828161
# Accuracy STD  0.051216  0.055423       0.062404         0.061061
# AUC-ROC       0.914286  0.755185       0.899073         0.900859
# AUC-ROC STD   0.033670  0.059216       0.042552         0.044040
#
#               SVM-NuSVC-model.1  SVM-LinearSVC-model  SVM-LinearSVC-model.1  \
# Accuracy               0.838046             0.844828               0.851494
# Accuracy STD           0.058579             0.051216               0.057570
# ...
